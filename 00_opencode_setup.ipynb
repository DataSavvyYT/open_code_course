# %% [markdown]
# <a href="https://colab.research.google.com/github/DataSavvyYT/open_code_course/blob/main/00_opencode_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install OpenCode
# !curl -fsSL https://opencode.ai/install | bash

# 2. Add the binary to your path (Colab specific)
import os
os.environ['PATH'] += ":/root/.opencode/bin"
# Out:
# Installing opencode version: 1.2.26
# ■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■ 100%
# Successfully added opencode to $PATH in /root/.bashrc
#
#                                  ▄
# █▀▀█ █▀▀█ █▀▀█ █▀▀▄ █▀▀▀ █▀▀█ █▀▀█ █▀▀█
# █░░█ █░░█ █▀▀▀ █░░█ █░░░ █░░█ █░░█ █▀▀▀
# ▀▀▀▀ █▀▀▀ ▀▀▀▀ ▀  ▀ ▀▀▀▀ ▀▀▀▀ ▀▀▀▀ ▀▀▀▀
#
#
# OpenCode includes free models, to start:
#
# cd <project>  # Open directory
# opencode      # Run command
#
# For more information visit https://opencode.ai/docs

# %%
# !opencode run "Explain the subword tokenization strategy in this directory"
# Out:
# Performing one time database migration, may take a few minutes...
# Database migration complete.
#
# > build · big-pickle
#
# ✱ Glob "**/*" 21 matches
# ✱ Grep "tokenization|subword|BPE|WordPiece" 0 matches
# ✱ Glob "**/*.py" 0 matches
# ✱ Glob "**/*token*" 0 matches
#
# There's no subword tokenization code in this directory. The directory contains only data files (CSV, JSON), config files, and logs. Could you point me to a different directory or clarify which codebase you'd like me to analyze?

# %% [markdown]
# # **The Interactive Terminal (Recommended)**
# To use the full OpenCode TUI, you should use Colab's built-in terminal (available for Colab Pro/Enterprise) or a library like colab-xterm.

# %%
# !pip install colab-xterm
# %load_ext colab_xterm
# %xterm
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_336/3371302958.py in <cell line: 0>()
#       1 get_ipython().system('pip install colab-xterm')
# ----> 2 get_ipython().run_line_magic('load_ext', 'colab_xterm')
#       3 get_ipython().run_line_magic('xterm', '')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...

# %%
# In a cell before starting opencode
from google.colab import userdata
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
